# %% [markdown]
# # Dependancies

# %%
# %matplotlib inline

## Import Dependancies ##
import re
import glob
import pandas as pd
import numpy as np
import math
from math import ceil, floor
from sklearn.datasets import load_digits
from scipy.spatial import ConvexHull
import matplotlib.pyplot as plt
import os
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
from skimage import measure

# opens plotly in browser
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "browser"


#import classes
import Image_Classes as im
from Image_Classes import *

# %% [markdown]
# # Examples: Initialise class Check_Segmentations()

# %%
# plot all cells
ex_all_cells = im.Check_Segmentation(dir_path='I05_multiOrganelles_Linked/', mito=False, nuclei=True, cyto=False, subset=None)

# %%
# examples of plotting subsets of cells
ex_subset1 = im.Check_Segmentation(dir_path='I05_multiOrganelles_Linked/', mito=False, nuclei=True, cyto=False, subset=[1, 2, 10])
ex_subset2 = im.Check_Segmentation(dir_path='I05_multiOrganelles_Linked/', mito=False, nuclei=True, cyto=False, subset=[2])
ex_subset3 = im.Check_Segmentation(dir_path='I05_multiOrganelles_Linked/', mito=False, nuclei=True, cyto=False, subset=range(1, 3))

# %%
# choose organelles to plot
ex_mito = im.Check_Segmentation(dir_path='I05_multiOrganelles_Linked/', mito=True, nuclei=False, cyto=False, subset=[2])
ex_mito_and_nuclei = im.Check_Segmentation(dir_path='I05_multiOrganelles_Linked/', mito=True, nuclei=True, cyto=False, subset=[2])
ex_all = im.Check_Segmentation(dir_path='I05_multiOrganelles_Linked/', mito=True, nuclei=True, cyto=True, subset=[2])

# %% [markdown]
# # Plot cells

# %%
# all nuclei as convex hull 
# can't currently cope with plotting them all as scatter - working on it
ex_all_cells.plot_organelles_as_convex_hull()

# %%
ex_subset1.plot_organelles_as_scatter()

# %%
ex_subset1.plot_organelles_as_convex_hull()

# %%
ex_mito.plot_organelles_as_scatter()

# %%
ex_mito.plot_organelles_as_convex_hull()

# %%
ex_mito_and_nuclei.plot_organelles_as_scatter()

# %%
ex_mito_and_nuclei.plot_organelles_as_convex_hull()

# %% [markdown]
# # Examples: Initialise class Slice_Maker()

# %%
ex_all_cells_slices = im.Slice_Maker(dir_path='I05_multiOrganelles_Linked/', mito=False, nuclei=True, cyto=False, subset=None, image_size=100)

# %%
# supply the numerical label of the cell you want to plot slices for
ex_all_cells_slices.plot_slices(2)

# %%
ex_all_cells_slices.plot_organelles_as_marching_cubes(2)
# Out:
# /Users/esthomas/Mirror/Andor_Rotation/github_repo/3D_cells/Image_Classes.py:454: FutureWarning:
#
# marching_cubes_lewiner is deprecated in favor of marching_cubes. marching_cubes_lewiner will be removed in version 0.19
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ex_cell_slice = im.Slice_Maker(dir_path='I05_multiOrganelles_Linked/', mito=True, nuclei=True, cyto=False, subset=[2], image_size=100)

# %%
# %matplotlib inline
ex_cell_slice.plot_slices(2)

# %%
ex_cell_slice.plot_organelles_as_marching_cubes(2)
# Out:
# /Users/esthomas/Mirror/Andor_Rotation/github_repo/3D_cells/Image_Classes.py:454: FutureWarning:
#
# marching_cubes_lewiner is deprecated in favor of marching_cubes. marching_cubes_lewiner will be removed in version 0.19
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ex_mito_slice = im.Slice_Maker(dir_path='I05_multiOrganelles_Linked/', mito=True, nuclei=False, cyto=False, subset=[2], image_size=100)

# %%
ex_mito_slice.plot_organelles_as_marching_cubes(2)
# Out:
# /Users/esthomas/Mirror/Andor_Rotation/github_repo/3D_cells/Image_Classes.py:454: FutureWarning:
#
# marching_cubes_lewiner is deprecated in favor of marching_cubes. marching_cubes_lewiner will be removed in version 0.19
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
